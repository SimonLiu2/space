# %%
from Function import Function as F
from Function import *

# %%
x = np.linspace(0, 1, 512)
y = np.sin(2*np.pi*10*x) + np.random.normal(0, 0.1, 512)

plt.plot(y)
plt.show()

y= F.filter_fft(y, type='highpass')
plt.plot(y)
